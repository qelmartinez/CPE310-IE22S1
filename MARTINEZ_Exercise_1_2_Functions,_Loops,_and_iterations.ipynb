# %% [markdown]
# <a href="https://colab.research.google.com/github/qelmartinez/CPE310-IE22S1/blob/main/MARTINEZ_Exercise_1_2_Functions%2C_Loops%2C_and_iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1.2 Functions, Loops, and iterations**
#
#
#
# ---
#
#
# **Name:** name  <br>
# **Section:** section <br>
# **Date Submitted:** date<br>
#
#
#
#
# ---

# %% [markdown]
# ## **Part 1: Functions**

# %% [markdown]
# **Exercise 1: What is the purpose of the “def” keyword in Python?**
# <br>
# a) It is slang that means “the following code is really cool”
# <br>
# b) It indicates the start of a function
# <br>
# c) It indicates that the following indented section of code is to be stored for later
# <br>
# d) b and c are both true
# <br>
# e) None of the above

# %% [markdown]
# **Answer: D**

# %% [markdown]
# Exercise 2: What will the following Python program print out?
#
# a) Zap ABC jane fred jane <br>
# b) Zap ABC Zap <br>
# c) ABC Zap jane <br>
# d) ABC Zap ABC <br>
# e) Zap Zap Zap <br>

# %%
def fred():
   print("Zap")

def jane():
   print("ABC")

jane()
fred()
jane()
# Out:
# ABC
# Zap
# ABC

# %% [markdown]
# **Answer: D**

# %% [markdown]
# **Exercise 3:** Rewrite your pay computation with time-and-a-half for overtime and create a function called computepay which takes two parameters (hours and rate).

# %% [markdown]
# ```
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0
# ```

# %%
#answer here
def computepay (hours, rate):
  if hours > 40:
    overtime = hours - 40
    pay = (40*rate) + (overtime * rate * 1.5)
  else:
    pay = hours * rate
  return pay

hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = computepay(hours, rate)
print ("Pay: ", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay:  475.0

# %% [markdown]
# **Exercise 4:** Rewrite the grade program from the previous chapter using a function called computegrade that takes a score as its parameter and returns a grade as a string.

# %% [markdown]
# ```
#   Score   Grade
# >= 0.9     A
# >= 0.8     B
# >= 0.7     C
# >= 0.6     D
#  < 0.6     F
# Enter score: 0.95
# A
# Enter score: perfect
# Bad score
# Enter score: 10.0
# Bad score
# Enter score: 0.75
# C
# Enter score: 0.5
# F ```

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: 0.98
# A

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: .8
# B

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: .7
# C

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: 0.6
# D

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: .5
# F

# %%
#answer here
def computegrade (score):
  if score <0.0 or score > 1.0:
    grade = "Bad Score"
    return grade
  elif score >= 0.9:
    grade = "A"
    return grade
  elif score >= 0.8:
    grade = "B"
    return grade
  elif score >= 0.7:
    grade = "C"
    return grade
  elif score >= 0.6:
    grade = "D"
    return grade
  else:
    grade = "F"
    return grade


#for invalid inputs
try:
  score = float(input("Enter Score: "))
  grade = computegrade(score)
  print (grade)

except:
  print ("Bad Score")
# Out:
# Enter Score: perfect
# Bad Score

# %% [markdown]
# ## **Part 2: Loops and Iterations**

# %%
#answer here

# %% [markdown]
# **Exercise 1:** Write a program which repeatedly reads integers until the user enters “done”. Once “done” is entered, print out the total, count, and average of the integers. If the user enters anything other than a integers, detect their mistake using try and except and print an error message and skip to the next integers.

# %%
from typing import Counter
#answer here

total = 0
count = 0

while True:
  num = int(input("Enter a number: "))
  if num == "done":
   ave = total / count
   print (ave)
   break
  else:
    total = num + total
    count = count + 1
    continue

try:
  num = int(input("Enter a number: "))
  if num == "done":
    ave = total / count
  print (ave)
except:
  print ("Invalid input")
# Out:
# Enter a number: 43
# Enter a number: 6
# Enter a number: 34
# Enter a number: done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2586160378.py in <cell line: 0>()
#       6
#       7 while True:
# ----> 8   num = int(input("Enter a number: "))
#       9   if num == "done":
#      10    ave = total / count
#
# ValueError: invalid literal for int() with base 10: 'done'

# %% [markdown]
# 2**Exercise 2:** Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %%
#answer here
